# %% [markdown]
# # AmalJob Scraping

# %%
import lxml
import requests
import urllib
import pandas as pd
import matplotlib.pyplot as plt
from math import pi
from bs4 import BeautifulSoup as bs

# %%
import os
os.environ['http_proxy'] = "http://ensias-tp:wpass1234@10.23.201.11:3128" 
os.environ['https_proxy'] = "https://ensias-tp:wpass1234@10.23.201.11:3128"

# %%
# Out:
# 200
# utf-8

# %% [markdown]
# #### Initialisation du table de donnees

# %%
columns = ['offerName', 'Entreprise', 'Région', 'Type de contrat', 'Salaire',  "Secteur d'activité", 'Fonction', 'Expérience', 'Type de formation', 'Date création', 'Date expiration', 'Desc_Entreprise', 'Desc_Fonction', 'Desc_Profil']
df = pd.DataFrame(columns=columns)
df.head()
# Out:
# Empty DataFrame
# Columns: [offerName, Entreprise, Région, Type de contrat, Salaire, Secteur d'activité, Fonction, Expérience, Type de formation, Date création, Date expiration, Desc_Entreprise, Desc_Fonction, Desc_Profil]
# Index: []

# %%
url = "https://www.amaljob.com/liste-offres-emploi-maroc?motcle=Business+Intelligence&region=&rechercher=rechercher"
req =requests.get(url)
status = req.status_code
req.encoding = 'utf-8'
encoding = req.encoding
print(status)
print(encoding)
print("----------------------------------")
html_doc = req.text
soup = bs(html_doc, 'html.parser')
data = soup.find_all('a', {'class' : 'voirOffre_itemOffre stylBtn1'})

for elt in data:    
    
    # lien de l'offre
    lien = elt.get('href')
    
    # details de connection a ce lien
    r =requests.get(lien)
    print(r.status_code)
    r.encoding = 'utf-8'
    html_document = req.text
    print(html_document)
    s = bs(html_document, 'html.parser')
    
    # Extraction de champs
    dic = {}
    dt = s.find('h1', {'class' : 'titre5'})
    dic['offre'] = dt
    
    
    print(dic)
    
    break
# Out:
# 200
# utf-8
# ----------------------------------
# 200
#
#
#     <!DOCTYPE html>
#     <html lang="fr">
#
#     <head>
#         <meta charset="utf-8">
#         <meta http-equiv="X-UA-Compatible" content="IE=edge">
#         <meta name="viewport" content="width=device-width, initial-scale=1">
#         <!-- The above 3 meta tags *must* come first in the head; any other head content must come *after* these tags -->
#         <!-- BEGIN   ======   Google fonts Roboto -->
#         <!-- Example :
#                 font-family: 'Roboto', sans-serif;
#              -->
#         <link href="https://fonts.googleapis.com/css?family=Roboto" rel="stylesheet">
#
#         <!-- END   ======   Google fonts Roboto -->
#
#         <!-- BEGIN   ======   BOOTSTRAP -->
#         <!-- Latest compiled and minified CSS -->
# ...
